# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmerajesh4990/AIpracticeandtraining/blob/main/Practice%20paper%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#while loop
num = 2

while num <= 10:
    print("Even number:", num)
    num = num + 2
# Out:
# Even number: 2
# Even number: 4
# Even number: 6
# Even number: 8
# Even number: 10

# %%
x=75
if(x>100):
   print("x is big number")
else:
   print("x is small number")
# Out:
# x is small number

# %%
# Suppose you scored 450 out of 600
marks_obtained = 450
total_marks = 600

percentage = (marks_obtained / total_marks) * 100
print("Your percentage is:", percentage, "%")
# Out:
# Your percentage is: 75.0 %

# %%
x = 25
if(x%25== 0):
  print("x is even number")
else:
  print("x is odd number")
# Out:
# x is odd number

# %%
#for loop
fruits_list = ["apple", "banana", "cherry"]
for fruit in fruits_list:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
#dict
student = {
    "name": "Rajesh",
    "age": 30,
    "city": "Abu Dhabi"
}
print(student)
print(student["name"], "is", student["age"], "years old and lives in", student["city"])
# Out:
# {'name': 'Rajesh', 'age': 30, 'city': 'Abu Dhabi'}
# Rajesh is 30 years old and lives in Abu Dhabi

# %%
#dict
Names = {'Rajesh', 'Ali','kiran','ajay','ravi'}
Numbers= {50001, 90001, 20001,4001,34532}
print(Names)
print(Numbers)
# Out:
# {'ajay', 'kiran', 'Ali', 'ravi', 'Rajesh'}
# {4001, 20001, 50001, 34532, 90001}

# %%
# --- 3. Control Flow: The for Loop (Iteration) ---

# List of numbers to iterate over [3]
numbers = [1, 2, 3, 4, 5]
total = 0 # Initialize a running total at zero [3]

# Loop runs for every number in the list
# It grabs the 1, adds it, grabs the 2, adds it, and so on [3]
for num in numbers:
    total = total + num # Add the current number to the running total

# Prints the final result (1 + 2 + 3 + 4 + 5 = 15) [3]
print("sum of total value is",total)
# Expected Output: 15
# Out:
# sum of total value is 15

# %%
#dict
phone_book = {
    "Rajesh": "0501234567",
    "Ali": "0507654321",
    "Fatima": "0509876543"
}

for name, number in phone_book.items():
    print(name, ":", number)
# Out:
# Rajesh : 0501234567
# Ali : 0507654321
# Fatima : 0509876543

# %%
#dict
phone_book = {
    "Rajesh": "0501234567",
    "Ali": "0507654321",
    "Fatima": "0509876543"
}
print(phone_book)
# Out:
# {'Rajesh': '0501234567', 'Ali': '0507654321', 'Fatima': '0509876543'}

# %%
#Tuples
dimesnions = (1920,2001)
widht, height = dimesnions
print(widht)
print(height)
# Out:
# 1920
# 2001

# %%
#Tuples
student =("rajesh", 30, 5.7,72,"male","abudhabi")
print("student details are:",student)
print("student name is:",student[0])
print("studnet age is:",student[1])
# Out:
# student details are: ('rajesh', 30, 5.7, 72, 'male', 'abudhabi')
# student name is: rajesh
# studnet age is: 30

# %%
#Tuples
point=(24.45,54.38)
print(point)
print("longitude:",point[0])
print("latitude:",point[1])
# Out:
# (24.45, 54.38)
# longitude: 24.45
# latitude: 54.38

# %%
tuple=("rajesh", 30,"India")
print(tuple)
print(tuple[-1])
# Out:
# ('rajesh', 30, 'India')
# India

# %%
fruits_tuple= ("apple","orange","grapes","lemon")
#fruits_tuple[0]= "banana" ## this is not possible bcos in tuple we cannot add new items
print(fruits_tuple)
print(fruits_tuple[2])
# Out:
# ('apple', 'orange', 'grapes', 'lemon')
# grapes

# %%
numbers = [10, 20, 30]

# Add a new number
numbers.append(40)

# Change the first number
numbers[0] = 5

# Print all numbers
for num in numbers:
    print(num)
# Out:
# 5
# 20
# 30
# 40

# %%
fruits_list=['apple','orange','grapes','lemon','watermelon',]
fruits_list.append('banana')
#fruits_list.remove('lemon')
print(fruits_list[0])
print(fruits_list)
print(f"the list of fruits are: {fruits_list}")
print(f"the name of fruits are:{fruits_list}")
# Out:
# apple
# ['apple', 'orange', 'grapes', 'lemon', 'watermelon', 'banana']
# the list of fruits are: ['apple', 'orange', 'grapes', 'lemon', 'watermelon', 'banana']
# the name of fruits are:['apple', 'orange', 'grapes', 'lemon', 'watermelon', 'banana']

# %%
integer_Var=100
float_Var=3.25
string_Var="Hello world"
boolean_Var=True
print(integer_Var)
print(float_Var)
print(string_Var)
print(boolean_Var)
print("Float variable: " + str(float_Var))
# Out:
# 100
# 3.25
# Hello world
# True
# Float variable: 3.25

# %%
name_dict={"name":"rajesh","age":30,"country":"India"}
print(name_dict["name"])
print(name_dict["age"])
print(name_dict["country"])
# Out:
# rajesh
# 30
# India

# %%
name_tuple=('rajesh',30,"India")
print(name_tuple)
# Out:
# ('rajesh', 30, 'India')

# %%
name_list=["rajesh",30,"India"]
print(name_list)
# Out:
# ['rajesh', 30, 'India']

# %%
x = 10,20,50,60,70,80
print("the result of x", x[1:5])
# Out:
# the result of x (20, 50, 60, 70)

# %%
x = 10
y = 5
sum_result = f"The sum of {x} and {y} is {x + y}."
print(sum_result)
# Out:
# The sum of 10 and 5 is 15.

# %%
import requests

def get_joke():
    response = requests.get("https://official-joke-api.appspot.com/random_joke")
    data = response.json()
    return data["setup"] + " ... " + data["punchline"]

print(get_joke())
# Out:
# What do you do when you see a space man? ... Park your car, man.

# %%
# !pip install gradio

import gradio as gr

def greet(name):
    return f"Hello, {name}!"

# Create a simple interface
iface = gr.Interface(
    fn=greet,                  # function to run
    inputs=gr.Textbox(label="Enter your name"),   # input box
    outputs=gr.Textbox(label="Greeting")          # output box
)

# Launch the app
iface.launch()
# Out:
# ...
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://26f8375ee145d72d17.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://26f8375ee145d72d17.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
x=10
y=12
z=x+y
print(f"the value of z is equal to", z)
# Out:
# the value of z is equal to 22
